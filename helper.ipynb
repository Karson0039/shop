# %%
import glob, os
import numpy as np
import sys
import csv
import random
from datetime import datetime

dataPath="Data"
cashierFee=0.25 #Cost per min of a cashier

itemRange = [[0,9], [10,14], [15,19], [20,30], [31,40],[41,1000]] #Holds the ranges in which items are divided

#Data handling files
#-----------------------------------------------------------------------------------------
def toSeconds(time):
	if(time=='0'):
		return 0
	times=time.split(":")
	return (int(times[0])*60)+int(times[1].split(".")[0])

def getData():
    Queues = {}
    os.chdir("/Users/jaisy/Grocery Simulation/Data")
    for file in glob.glob("*.csv"):
        with open(file) as csvfile:
            data = csv.reader(csvfile, delimiter=',')
            next(data, None)
            arrival = []
            serviceStart = []
            serviceEnd = []  # Fix the variable name here
            droptime = []
            items = []
            card = []
            waitTime = []
            serviceTime = []
            for row in data:
                arrival.append(row[1])
                serviceStart.append(row[2])
                serviceEnd.append(row[3])
                droptime.append(row[6])
                items.append(row[7])
                card.append(row[8])
                waitTime.append(toSeconds(row[4]) if row[4] else 0)  # Check for empty string
                serviceTime.append(toSeconds(row[5]) if row[5] else 0)
            Queues[file] = (arrival, serviceStart, serviceEnd, droptime, items, card, waitTime, serviceTime)
    return Queues

def getElapsed(time1,time2):
	elapsed = datetime.strptime(time2, '%H:%M:%S') - datetime.strptime(time1, '%H:%M:%S')
	return elapsed.total_seconds()


#Basic Calculations
#-----------------------------------------------------------------------------------------
def getArrivalRate(queue):
	arrivals=queue[0]
	interArrivalTime=[]
	for i in range(1,len(arrivals)):
			interArrivalTime.append(getElapsed(arrivals[i-1],arrivals[i]))
	return 1/(np.mean(interArrivalTime)/60)

def getServiceRate(queue):
	time=queue[7]
	return 1/(np.mean(time)/60)

def getWaitTime(queue):
	time=queue[6]
	return np.mean(time)/60

def getServiceUtil(arrival,service):
	return arrival/service

#Gets the number of items in a simulated queue
def numItems(queue):
	items=0
	for customer in queue:
		items+=customer['items']
	return items
#-----------------------------------------------------------------------------------------

def getProbs(items): #takes in the array of num of items
	ranges = []
	for j in range(len(itemRange)): ranges.append(0)
	prob = []
	total = len(items)

	for k in range(len(items)): #gets rids of drop outs that was counted
		if items[k]==0:
			total -= 1

	for i in range(len(items)):
		for j in range(len(ranges)):
			if int(items[i]) >= itemRange[j][0] and int(items[i]) <= itemRange[j][1]:
				ranges[j] += 1
				#break

	total = float(total)
	for j in range(len(ranges)):
		prob.append(ranges[j]/total)

	return prob

# Accepts the queue and returns the time difference as a tuple the first value is for cash, second for card
def TimeDifference(queue):
	location = -1
	card = queue[5]
	service = queue[7]

	# Given you use a card/cash whats your average service time
	avgCard = []
	avgCash = []

	for truth in card:
		location += 1
		if truth == '1':
			avgCard.append(service[location])
		else:
			avgCash.append(service[location])
	avgCard = np.mean(avgCard)
	avgCash = np.mean(avgCash)
	
	if (avgCash > avgCard):
		return ( 1 / abs(avgCash-avgCard) / 60,0)

	return (0, 1 / abs(avgCash-avgCard) / 60)

def averageServiceTime(queue):
	item_ranges = []
	service_time_ranges = []
	average_service_time_ranges = []
	for i in range(len(itemRange)):
		item_ranges.append(0)
		service_time_ranges.append([])
		average_service_time_ranges.append(0)
	
	items = queue[4]
	service_rates = queue[7]
	#print queue
	for i in range(len(items)):
		current_items = items[i]
		current_service_rate = service_rates[i]

		for j in range(len(itemRange)):
			if int(items[i]) >= itemRange[j][0] and int(items[i]) <= itemRange[j][1]:
				item_ranges[j] += 1
				service_time_ranges[j].append(current_service_rate)

	for i in range(len(item_ranges)):
		if(len(service_time_ranges[i]) > 0):
			average_service_time_ranges[i] = np.mean(service_time_ranges[i])
		else: average_service_time_ranges[i] = 0

	print(item_ranges)
	print(service_time_ranges)
	print(average_service_time_ranges) 

def main():
    Queues = getData()
    for queue in Queues:
        print(queue)

        arr = getArrivalRate(Queues[queue])
        ser = getServiceRate(Queues[queue])
        wait = getWaitTime(Queues[queue])
        prob = getProbs(Queues[queue][4])
        timeDifference = TimeDifference(Queues[queue])

        print("Arrival Rate ", arr)
        print("Service Rate ", ser)
        print("Wait Time ", wait)
        print("Service Utilization ", getServiceUtil(arr, ser))
        print("Time Difference", timeDifference, '\n')

        averageServiceTime(Queues[queue])


if __name__ == "__main__":
    main()
# Out:
# Queue1.csv
# Arrival Rate  0.1798898174867893
# Service Rate  0.29122722914669225
# Wait Time  17.74897119341564
# Service Utilization  0.6176957354361193
# Time Difference (0, 0.0002283124594595367)
#
# [35, 11, 17, 18, 0, 0]
# [[80, 91, 82, 84, 70, 0, 0, 0, 151, 144, 66, 74, 221, 74, 244, 73, 218, 124, 0, 66, 234, 0, 169, 204, 256, 102, 114, 0, 0, 125, 223, 0, 135, 147, 116], [86, 156, 245, 199, 121, 229, 202, 334, 222, 183, 203], [269, 256, 310, 183, 316, 287, 249, 359, 343, 336, 194, 296, 277, 338, 320, 237, 216], [243, 295, 298, 415, 367, 284, 388, 376, 305, 306, 287, 299, 316, 375, 335, 395, 380, 371], [], []]
# [105.34285714285714, 198.1818181818182, 281.52941176470586, 335.27777777777777, 0, 0]
# Queue2.csv
# Arrival Rate  0.18021400412990426
# Service Rate  0.25658624148672193
# Wait Time  27.839917695473254
# Service Utilization  0.7023525621861145
# Time Difference (0, 0.0005059875189745318)
#
# [31, 10, 14, 18, 7, 1]
# [[151, 129, 170, 114, 85, 125, 110, 0, 0, 157, 100, 125, 145, 86, 65, 235, 90, 100, 199, 134, 136, 132, 111, 134, 61, 129, 138, 135, 193, 0, 74], [209, 196, 228, 178, 231, 273, 215, 213, 129, 201], [353, 312, 258, 228, 268, 339, 298, 255, 278, 295, 251, 280, 348, 379], [401, 239, 452, 407, 477, 221, 182, 333, 326, 367, 305, 174, 406, 461, 360, 288, 323, 382], [271, 521, 92, 483, 348, 307, 506], [531]]
# [114.93548387096774, 207.3, 295.85714285714283, 339.1111111111111, 361.14285714285717, 531.0]
# Queue3.csv
# Arrival Rate  0.19481973576173772
# Service Rate  0.2843601895734597
# Wait Time  17.196780303030305
# Service Utilization  0.685116070762111
# Time Difference (0, 0.0005936960276338516)
#
# [32, 16, 13, 25, 2, 0]
# [[108, 101, 62, 0, 64, 0, 113, 82, 161, 115, 173, 114, 111, 72, 196, 101, 281, 103, 167, 118, 154, 0, 97, 99, 140, 0, 118, 65, 0, 0, 0, 90], [223, 197, 181, 189, 183, 174, 155, 198, 206, 238, 280, 118, 229, 154, 269, 212], [250, 307, 246, 273, 342, 275, 250, 296, 346, 235, 322, 232, 313], [338, 221, 361, 392, 412, 305, 318, 339, 374, 352, 342, 326, 254, 235, 291, 393, 294, 281, 319, 307, 316, 282, 316, 254, 346], [380, 322], []]
# [93.90625, 200.375, 283.61538461538464, 318.72, 351.0, 0]
# Queue6.csv
# Arrival Rate  0.2651416688328568
# Service Rate  0.5126014523707818
# Wait Time  1.7879166666666668
# Service Utilization  0.5172472056147647
# Time Difference (0, nan)
#
# [33, 17, 9, 35, 24, 2]
# [[139, 0, 0, 0, 66, 96, 96, 96, 70, 112, 120, 147, 165, 65, 179, 177, 140, 125, 86, 79, 135, 0, 116, 0, 104, 122, 67, 137, 154, 171, 160, 82, 0], [157, 70, 174, 145, 110, 99, 68, 143, 172, 160, 60, 106, 163, 76, 155, 130, 141], [173, 171, 111, 175, 103, 145, 169, 68, 102], [179, 122, 164, 72, 113, 157, 153, 98, 139, 174, 165, 65, 178, 69, 89, 63, 166, 111, 89, 149, 146, 167, 115, 101, 113, 82, 178, 96, 164, 175, 140, 105, 113, 171, 166], [136, 66, 161, 117, 150, 67, 166, 154, 126, 74, 120, 88, 72, 89, 143, 76, 142, 140, 99, 138, 117, 84, 108, 124], [82, 108]]
# [97.15151515151516, 125.23529411764706, 135.22222222222223, 129.9142857142857, 114.875, 95.0]
# Queue4.csv
# Arrival Rate  0.274229198666317
# Service Rate  0.5241849563179203
# Wait Time  1.9284552845528455
# Service Utilization  0.5231535078622056
# Time Difference (0, nan)
#
# [38, 19, 18, 21, 26, 1]
# [[97, 124, 108, 121, 155, 117, 76, 71, 0, 0, 176, 166, 157, 171, 0, 101, 114, 125, 163, 77, 130, 108, 164, 95, 116, 144, 97, 111, 89, 0, 115, 0, 121, 115, 68, 168, 68, 106], [133, 117, 161, 147, 141, 67, 163, 167, 74, 114, 129, 106, 76, 78, 74, 82, 76, 130, 74], [149, 72, 177, 134, 157, 163, 62, 165, 90, 72, 64, 116, 119, 169, 92, 72, 86, 108], [239, 127, 104, 104, 141, 162, 169, 164, 130, 141, 114, 176, 67, 68, 151, 168, 116, 97, 94, 110, 63], [81, 155, 110, 171, 155, 161, 108, 121, 117, 89, 92, 99, 81, 165, 90, 81, 84, 176, 174, 118, 105, 145, 120, 143, 123, 88], [112]]
# [103.52631578947368, 111.0, 114.83333333333333, 128.8095238095238, 121.23076923076923, 112.0]
# Queue5.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-474f031556ce> in <module>
#     176
#     177 if __name__ == "__main__":
# --> 178     main()
#
# <ipython-input-38-474f031556ce> in main()
#     160         print(queue)
#     161
# --> 162         arr = getArrivalRate(Queues[queue])
#     163         ser = getServiceRate(Queues[queue])
#     164         wait = getWaitTime(Queues[queue])
#
# <ipython-input-38-474f031556ce> in getArrivalRate(queue)
#      57         interArrivalTime=[]
#      58         for i in range(1,len(arrivals)):
# ---> 59                         interArrivalTime.append(getElapsed(arrivals[i-1],arrivals[i]))
#      60         return 1/(np.mean(interArrivalTime)/60)
#      61
#
# <ipython-input-38-474f031556ce> in getElapsed(time1, time2)
#      47
#      48 def getElapsed(time1,time2):
# ---> 49         elapsed = datetime.strptime(time2, '%H:%M:%S') - datetime.strptime(time1, '%H:%M:%S')
#      50         return elapsed.total_seconds()
#      51
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '' does not match format '%H:%M:%S'
